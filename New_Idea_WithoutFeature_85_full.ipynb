# %%
import os
import scipy.io
import numpy as np
from scipy import signal

data_path = "/kaggle/input/control1"
lowcut = 0.4 
highcut = 100 
fs_original = 500
fs_new = 250

control_data = []
control_path = os.path.join(data_path, 'Control')

for foldername in os.listdir(control_path):
    subfolder_path = os.path.join(control_path, foldername)
    control_data.append(subfolder_path)

Control30 = []

for control_data_path in control_data:
    n_epochs = 70 
    start_epoch = 1
    end_epoch = 110

    control_arr = []

    for i in range(start_epoch, end_epoch+1):
        epoch_path = os.path.join(control_data_path, f"trial{i}.mat")
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]    
        #print(mat_data1.shape)
        # Downsampling
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)
        #print(downsampled_data.shape)
        
        control_arr.append(downsampled_data)
        Control30.append(downsampled_data)

Control30 = np.array(Control30)

print(Control30.shape)
# Out:
# (3300, 60, 1000)

# %%
import os
import scipy.io
import numpy as np
from scipy import signal
data_path = "/kaggle/input/concussed1"
lowcut = 0.4 
highcut = 100 
fs_original = 500
fs_new = 250  

concussed_data = []
concussed_path = os.path.join(data_path, 'Concussed')
for foldername in os.listdir(concussed_path):
    subfolder_path = os.path.join(concussed_path, foldername)
    concussed_data.append(subfolder_path)

Concussed52 = []
for concussed_data_path in concussed_data:
    n_epochs = 70
    start_epoch = 1
    end_epoch = 110
    concussed_arr = []

    for i in range(start_epoch, end_epoch+1):
        epoch_path = f"{concussed_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)
        
        concussed_arr.append(np.array(downsampled_data))
        
        Concussed52.append(downsampled_data)

Concussed52 = np.array(Concussed52)

print( Concussed52.shape)
# Out:
# (5390, 60, 1000)

# %%
from scipy.stats import entropy

alpha_band = (8, 12)
beta_band = (12, 35)
delta_band = (.5, 4)
epsilon = 1e-10

Concussed_feature = np.zeros((Concussed52.shape[0], Concussed52.shape[1], Concussed52.shape[2] + 4))

for i in range(Concussed52.shape[0]):
    for j in range(Concussed52.shape[1]):
        channel_data = Concussed52[i, j, :]
        freq_spectrum = np.fft.fft(channel_data)
        power_spectrum = np.abs(freq_spectrum) ** 2

        alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
        beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
        delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

        channel_min_value = np.min(channel_data)
        channel_max_value = np.max(channel_data)

        power_spectrum_adjusted = power_spectrum + epsilon
        entropy_values = entropy(power_spectrum_adjusted)
        values = np.array([alpha_power, beta_power, delta_power, entropy_values])
        rescaled_values = (values - values.min()) * (channel_max_value - channel_min_value) / (values.max() - values.min()) + channel_min_value
        concatenated_data = np.concatenate((channel_data, rescaled_values))

        Concussed_feature[i, j, :-4] = channel_data
        Concussed_feature[i, j, -4:] = rescaled_values

print(Concussed_feature.shape)
# Out:
# (5390, 60, 1004)

# %%
dataset = np.concatenate((Control30, Concussed52), axis=0)
labels = np.concatenate((np.zeros(Control30.shape[0]), np.ones(Concussed52.shape[0])))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.2, random_state=42)
mean = np.mean(X_train)
std = np.std(X_train)

X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

model = Sequential()
model.add(Conv1D(32, 3, activation='relu', input_shape=(60,1000)))
model.add(MaxPooling1D(2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history=model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Epoch 1/100
# 218/218 [==============================] - 6s 23ms/step - loss: 0.6398 - accuracy: 0.6528
# Epoch 2/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.5581 - accuracy: 0.7090
# Epoch 3/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.4734 - accuracy: 0.7759
# Epoch 4/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.4281 - accuracy: 0.8039
# Epoch 5/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.3732 - accuracy: 0.8265
# Epoch 6/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.3707 - accuracy: 0.8403
# Epoch 7/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.2776 - accuracy: 0.8815
# Epoch 8/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.2173 - accuracy: 0.9097
# Epoch 9/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.2041 - accuracy: 0.9202
# Epoch 10/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.2218 - accuracy: 0.9151
# Epoch 11/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.1994 - accuracy: 0.9220
# Epoch 12/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.1265 - accuracy: 0.9514
# Epoch 13/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0707 - accuracy: 0.9783
# Epoch 14/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0496 - accuracy: 0.9869
# Epoch 15/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0378 - accuracy: 0.9905
# Epoch 16/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.0953 - accuracy: 0.9708
# Epoch 17/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0598 - accuracy: 0.9807
# Epoch 18/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.0848 - accuracy: 0.9751
# Epoch 19/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.2911 - accuracy: 0.9151
# Epoch 20/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0649 - accuracy: 0.9796
# Epoch 21/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0295 - accuracy: 0.9928
# Epoch 22/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0117 - accuracy: 0.9990
# Epoch 23/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0080 - accuracy: 0.9997
# Epoch 24/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 25/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 26/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 27/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 28/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 29/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 30/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 31/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 32/100
# 218/218 [==============================] - 5s 22ms/step - loss: 8.5136e-04 - accuracy: 1.0000
# Epoch 33/100
# 218/218 [==============================] - 5s 22ms/step - loss: 7.3901e-04 - accuracy: 1.0000
# Epoch 34/100
# 218/218 [==============================] - 5s 22ms/step - loss: 6.3654e-04 - accuracy: 1.0000
# Epoch 35/100
# 218/218 [==============================] - 5s 22ms/step - loss: 5.4125e-04 - accuracy: 1.0000
# Epoch 36/100
# 218/218 [==============================] - 5s 22ms/step - loss: 4.6780e-04 - accuracy: 1.0000
# Epoch 37/100
# 218/218 [==============================] - 5s 22ms/step - loss: 4.0025e-04 - accuracy: 1.0000
# Epoch 38/100
# 218/218 [==============================] - 5s 24ms/step - loss: 3.5111e-04 - accuracy: 1.0000
# Epoch 39/100
# 218/218 [==============================] - 5s 22ms/step - loss: 3.0216e-04 - accuracy: 1.0000
# Epoch 40/100
# 218/218 [==============================] - 5s 22ms/step - loss: 2.6158e-04 - accuracy: 1.0000
# Epoch 41/100
# 218/218 [==============================] - 5s 22ms/step - loss: 2.2670e-04 - accuracy: 1.0000
# Epoch 42/100
# 218/218 [==============================] - 5s 22ms/step - loss: 1.9550e-04 - accuracy: 1.0000
# Epoch 43/100
# 218/218 [==============================] - 5s 22ms/step - loss: 1.7301e-04 - accuracy: 1.0000
# Epoch 44/100
# 218/218 [==============================] - 5s 24ms/step - loss: 1.5001e-04 - accuracy: 1.0000
# Epoch 45/100
# 218/218 [==============================] - 5s 23ms/step - loss: 1.3119e-04 - accuracy: 1.0000
# Epoch 46/100
# 218/218 [==============================] - 5s 22ms/step - loss: 1.1510e-04 - accuracy: 1.0000
# Epoch 47/100
# 218/218 [==============================] - 5s 23ms/step - loss: 1.0038e-04 - accuracy: 1.0000
# Epoch 48/100
# 218/218 [==============================] - 5s 22ms/step - loss: 8.8033e-05 - accuracy: 1.0000
# Epoch 49/100
# 218/218 [==============================] - 5s 22ms/step - loss: 7.6467e-05 - accuracy: 1.0000
# Epoch 50/100
# 218/218 [==============================] - 5s 22ms/step - loss: 6.6919e-05 - accuracy: 1.0000
# Epoch 51/100
# 218/218 [==============================] - 5s 24ms/step - loss: 5.8697e-05 - accuracy: 1.0000
# Epoch 52/100
# 218/218 [==============================] - 5s 22ms/step - loss: 5.1070e-05 - accuracy: 1.0000
# Epoch 53/100
# 218/218 [==============================] - 5s 22ms/step - loss: 4.4736e-05 - accuracy: 1.0000
# Epoch 54/100
# 218/218 [==============================] - 5s 23ms/step - loss: 3.9262e-05 - accuracy: 1.0000
# Epoch 55/100
# 218/218 [==============================] - 5s 22ms/step - loss: 3.4156e-05 - accuracy: 1.0000
# Epoch 56/100
# 218/218 [==============================] - 5s 22ms/step - loss: 3.0171e-05 - accuracy: 1.0000
# Epoch 57/100
# 218/218 [==============================] - 5s 24ms/step - loss: 2.7623e-05 - accuracy: 1.0000
# Epoch 58/100
# 218/218 [==============================] - 5s 22ms/step - loss: 2.3439e-05 - accuracy: 1.0000
# Epoch 59/100
# 218/218 [==============================] - 5s 22ms/step - loss: 2.0404e-05 - accuracy: 1.0000
# Epoch 60/100
# 218/218 [==============================] - 5s 23ms/step - loss: 1.7778e-05 - accuracy: 1.0000
# Epoch 61/100
# 218/218 [==============================] - 5s 22ms/step - loss: 1.5793e-05 - accuracy: 1.0000
# Epoch 62/100
# 218/218 [==============================] - 5s 22ms/step - loss: 1.3798e-05 - accuracy: 1.0000
# Epoch 63/100
# 218/218 [==============================] - 5s 23ms/step - loss: 1.2338e-05 - accuracy: 1.0000
# Epoch 64/100
# 218/218 [==============================] - 5s 23ms/step - loss: 1.0745e-05 - accuracy: 1.0000
# Epoch 65/100
# 218/218 [==============================] - 5s 23ms/step - loss: 9.4311e-06 - accuracy: 1.0000
# Epoch 66/100
# 218/218 [==============================] - 5s 22ms/step - loss: 8.3884e-06 - accuracy: 1.0000
# Epoch 67/100
# 218/218 [==============================] - 5s 22ms/step - loss: 7.4076e-06 - accuracy: 1.0000
# Epoch 68/100
# 218/218 [==============================] - 5s 22ms/step - loss: 6.5158e-06 - accuracy: 1.0000
# Epoch 69/100
# 218/218 [==============================] - 7s 33ms/step - loss: 5.7098e-06 - accuracy: 1.0000
# Epoch 70/100
# 218/218 [==============================] - 8s 36ms/step - loss: 5.0187e-06 - accuracy: 1.0000
# Epoch 71/100
# 218/218 [==============================] - 7s 31ms/step - loss: 4.4300e-06 - accuracy: 1.0000
# Epoch 72/100
# 218/218 [==============================] - 5s 22ms/step - loss: 3.8926e-06 - accuracy: 1.0000
# Epoch 73/100
# 218/218 [==============================] - 5s 22ms/step - loss: 3.4544e-06 - accuracy: 1.0000
# Epoch 74/100
# 218/218 [==============================] - 5s 22ms/step - loss: 3.0301e-06 - accuracy: 1.0000
# Epoch 75/100
# 218/218 [==============================] - 5s 23ms/step - loss: 2.6620e-06 - accuracy: 1.0000
# Epoch 76/100
# 218/218 [==============================] - 5s 23ms/step - loss: 2.3497e-06 - accuracy: 1.0000
# Epoch 77/100
# 218/218 [==============================] - 5s 23ms/step - loss: 2.0879e-06 - accuracy: 1.0000
# Epoch 78/100
# 218/218 [==============================] - 5s 22ms/step - loss: 1.9022e-06 - accuracy: 1.0000
# Epoch 79/100
# 218/218 [==============================] - 5s 23ms/step - loss: 1.6344e-06 - accuracy: 1.0000
# Epoch 80/100
# 218/218 [==============================] - 5s 22ms/step - loss: 1.4391e-06 - accuracy: 1.0000
# Epoch 81/100
# 218/218 [==============================] - 5s 22ms/step - loss: 1.2691e-06 - accuracy: 1.0000
# Epoch 82/100
# 218/218 [==============================] - 5s 24ms/step - loss: 1.1101e-06 - accuracy: 1.0000
# Epoch 83/100
# 218/218 [==============================] - 5s 22ms/step - loss: 9.8307e-07 - accuracy: 1.0000
# Epoch 84/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.2679 - accuracy: 0.9226
# Epoch 85/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.5111 - accuracy: 0.7691
# Epoch 86/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.3439 - accuracy: 0.8619
# Epoch 87/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.1995 - accuracy: 0.9205
# Epoch 88/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.0999 - accuracy: 0.9627
# Epoch 89/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0426 - accuracy: 0.9837
# Epoch 90/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.0580 - accuracy: 0.9822
# Epoch 91/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0218 - accuracy: 0.9944
# Epoch 92/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0093 - accuracy: 0.9981
# Epoch 93/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 94/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0215 - accuracy: 0.9937
# Epoch 95/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.0556 - accuracy: 0.9843
# Epoch 96/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.1411 - accuracy: 0.9584
# Epoch 97/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0268 - accuracy: 0.9931
# Epoch 98/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0111 - accuracy: 0.9970
# Epoch 99/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0066 - accuracy: 0.9990
# Epoch 100/100
# 218/218 [==============================] - 5s 22ms/step - loss: 0.0025 - accuracy: 0.9997

# %%
_, accuracy = model.evaluate(X_test, y_test)
print("Accuracy: %.2f%%" % (accuracy * 100))
# Out:
# 55/55 [==============================] - 1s 9ms/step - loss: 0.9854 - accuracy: 0.8487
# Accuracy: 84.87%

# %%
y_pred = model.predict(X_test)
y_pred = np.round(y_pred).flatten()
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# 55/55 [==============================] - 1s 10ms/step
# Confusion Matrix:
# [[537 147]
#  [116 938]]

# %%
from sklearn.metrics import classification_report
target_names = ['Control', 'Concussed']
report = classification_report(y_test, y_pred, target_names=target_names)
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      Control       0.82      0.79      0.80       684
#    Concussed       0.86      0.89      0.88      1054
#
#     accuracy                           0.85      1738
#    macro avg       0.84      0.84      0.84      1738
# weighted avg       0.85      0.85      0.85      1738

# %%
import seaborn as sns
import matplotlib.pyplot as plt

target_names = ['Control', 'Concussed']
report = classification_report(y_test, y_pred, target_names=target_names)
print("Classification Report:")
print(report)
cm = confusion_matrix(y_test, y_pred)

group_percentages = ["{0:.2%}".format(value) for value in cm.flatten() / np.sum(cm)]
group_counts = ["{0:0.0f}".format(value) for value in cm.flatten()]

labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2, 2)

ax = sns.heatmap(cm, fmt='', annot=labels, cmap='Greens')
ax.set_title('Confusion Matrix\n')
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('\nActual Values\n')
ax.xaxis.set_ticklabels(target_names)
ax.yaxis.set_ticklabels(target_names)

plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      Control       0.82      0.79      0.80       684
#    Concussed       0.86      0.89      0.88      1054
#
#     accuracy                           0.85      1738
#    macro avg       0.84      0.84      0.84      1738
# weighted avg       0.85      0.85      0.85      1738

# %%
from sklearn.metrics import roc_curve, roc_auc_score

X_test_norm = (X_test - mean) / std
y_pred_prob = model.predict(X_test_norm)

y_pred_prob_positive = y_pred_prob[:, 0]

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob_positive)
roc_auc = roc_auc_score(y_test, y_pred_prob_positive)

plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# 55/55 [==============================] - 0s 8ms/step
