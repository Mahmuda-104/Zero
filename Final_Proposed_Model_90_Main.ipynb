# %%
import os
import scipy.io
import numpy as np
from scipy import signal

data_path = "/kaggle/input/control1"
lowcut = 0.4 
highcut = 100 
fs_original = 500
fs_new = 250

control_data = []
control_path = os.path.join(data_path, 'Control')

for foldername in os.listdir(control_path):
    subfolder_path = os.path.join(control_path, foldername)
    control_data.append(subfolder_path)

Control30 = []

for control_data_path in control_data:
    n_epochs = 70 
    start_epoch = 1
    end_epoch = 110

    control_arr = []

    for i in range(start_epoch, end_epoch+1):
        epoch_path = os.path.join(control_data_path, f"trial{i}.mat")
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]    
        #print(mat_data1.shape)
        f0 = 60  
        Q = 30  
        w0 = f0 / (fs_original / 2)
        b, a = signal.iirnotch(w0, Q)
        filtered_data = signal.lfilter(b, a, mat_data1)
        
        # Downsampling
        num_samples_original = filtered_data.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(filtered_data, num_samples_new, axis=-1)
        #print(downsampled_data.shape)
        
        control_arr.append(downsampled_data)
        Control30.append(downsampled_data)

Control30 = np.array(Control30)

print(Control30.shape)
# Out:
# (3300, 60, 1000)

# %%
import numpy as np
from scipy.stats import entropy
from scipy import signal

epsilon = 1e-8
alpha_band = (8, 12)
beta_band = (12, 30)
delta_band = (0.5, 4)

num_samples = Control30.shape[0]
num_channels = Control30.shape[1]

features_control = np.zeros((num_samples, num_channels, 4))

for sample_idx in range(num_samples):
    for channel_idx in range(num_channels):
        channel_data = Control30[sample_idx, channel_idx, :]

        freq_spectrum = np.fft.fft(channel_data)
        power_spectrum = np.abs(freq_spectrum) ** 2

        alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
        beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
        delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

        channel_min_value = np.min(channel_data)
        channel_max_value = np.max(channel_data)

        power_spectrum_adjusted = power_spectrum + epsilon
        entropy_values = entropy(power_spectrum_adjusted)

        values = np.array([alpha_power, beta_power, delta_power, entropy_values])
        rescaled_values = (values - values.min()) * (channel_max_value - channel_min_value) / (values.max() - values.min()) + channel_min_value

        features_control[sample_idx, channel_idx, :] = rescaled_values

print(features_control.shape)
# Out:
# (3300, 60, 4)

# %%
import os
import scipy.io
import numpy as np
from scipy import signal
data_path = "/kaggle/input/concussed1"
lowcut = 0.4 
highcut = 100 
fs_original = 500
fs_new = 250  

concussed_data = []
concussed_path = os.path.join(data_path, 'Concussed')
for foldername in os.listdir(concussed_path):
    subfolder_path = os.path.join(concussed_path, foldername)
    concussed_data.append(subfolder_path)

Concussed52 = []
for concussed_data_path in concussed_data:
    n_epochs = 70
    start_epoch = 1
    end_epoch = 110
    concussed_arr = []

    for i in range(start_epoch, end_epoch+1):
        epoch_path = f"{concussed_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        f0 = 60 
        Q = 30  
        w0 = f0 / (fs_original / 2)
        b, a = signal.iirnotch(w0, Q)
        filtered_data = signal.lfilter(b, a, mat_data1)
        
        # Downsampling
        num_samples_original = filtered_data.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(filtered_data, num_samples_new, axis=-1)
        
        concussed_arr.append(np.array(downsampled_data))
        
        Concussed52.append(downsampled_data)

Concussed52 = np.array(Concussed52)

print( Concussed52.shape)
# Out:
# (5390, 60, 1000)

# %%
import numpy as np
from scipy.stats import entropy
from scipy import signal

epsilon = 1e-8
alpha_band = (8, 12)
beta_band = (12, 30)
delta_band = (0.5, 4)

num_samples = Concussed52.shape[0]
num_channels = Concussed52.shape[1]
features_concussed = np.zeros((num_samples, num_channels, 4))

for sample_idx in range(num_samples):
    for channel_idx in range(num_channels):
        channel_data = Concussed52[sample_idx, channel_idx, :]

        freq_spectrum = np.fft.fft(channel_data)
        power_spectrum = np.abs(freq_spectrum) ** 2

        alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
        beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
        delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

        channel_min_value = np.min(channel_data)
        channel_max_value = np.max(channel_data)

        power_spectrum_adjusted = power_spectrum + epsilon
        entropy_values = entropy(power_spectrum_adjusted)

        values = np.array([alpha_power, beta_power, delta_power, entropy_values])
        rescaled_values = (values - values.min()) * (channel_max_value - channel_min_value) / (values.max() - values.min()) + channel_min_value

        features_concussed[sample_idx, channel_idx, :] = rescaled_values

print(features_concussed.shape)
# Out:
# (5390, 60, 4)

# %%
dataset = np.concatenate((Control30, Concussed52), axis=0)
labels = np.concatenate((np.zeros(Control30.shape[0]), np.ones(Concussed52.shape[0])))

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, concatenate, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping

X_train_control, X_test_control, y_train_control, y_test_control = train_test_split(Control30, np.zeros(Control30.shape[0]), test_size=0.2, random_state=42)
X_train_concussed, X_test_concussed, y_train_concussed, y_test_concussed = train_test_split(Concussed52, np.ones(Concussed52.shape[0]), test_size=0.2, random_state=42)

X_train_features_control, X_test_features_control, _, _ = train_test_split(features_control, np.zeros(features_control.shape[0]), test_size=0.2, random_state=42)
X_train_features_concussed, X_test_features_concussed, _, _ = train_test_split(features_concussed, np.ones(features_concussed.shape[0]), test_size=0.2, random_state=42)
X_train_eeg = np.concatenate((X_train_control, X_train_concussed))
X_test_eeg = np.concatenate((X_test_control, X_test_concussed))
X_train_features = np.concatenate((X_train_features_control, X_train_features_concussed))
X_test_features = np.concatenate((X_test_features_control, X_test_features_concussed))
y_train = np.concatenate((y_train_control, y_train_concussed))
y_test = np.concatenate((y_test_control, y_test_concussed))

eeg_input = Input(shape=(60, 1000))
conv1 = Conv1D(64, 3, activation='relu')(eeg_input)
maxpool1 = MaxPooling1D(2)(conv1)
flatten1 = Flatten()(maxpool1)
dropout1 = Dropout(0.5)(flatten1)

feature_input = Input(shape=(60, 4))
flatten2 = Flatten()(feature_input)

concatenated = concatenate([dropout1, flatten2])
batchnorm1 = BatchNormalization()(concatenated)

dense1 = Dense(128, activation='relu')(batchnorm1)
dropout2 = Dropout(0.5)(dense1)

output = Dense(1, activation='sigmoid')(dropout2)

model = Model(inputs=[eeg_input, feature_input], outputs=output)
model.compile(optimizer=Adam(learning_rate=0.003), loss='binary_crossentropy', metrics=['accuracy'])

def lr_scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch > 0:
        return lr * 0.5
    return lr

lr_callback = LearningRateScheduler(lr_scheduler)

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
history = model.fit([X_train_eeg, X_train_features], y_train, epochs=100, batch_size=256, validation_data=([X_test_eeg, X_test_features], y_test), callbacks=[lr_callback, early_stopping])
test_loss, test_accuracy = model.evaluate([X_test_eeg, X_test_features], y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 10s 294ms/step - loss: 0.8564 - accuracy: 0.6244 - val_loss: 1.0266 - val_accuracy: 0.6536 - lr: 0.0030
# Epoch 2/100
# 28/28 [==============================] - 15s 552ms/step - loss: 0.6319 - accuracy: 0.6904 - val_loss: 0.5740 - val_accuracy: 0.6893 - lr: 0.0030
# Epoch 3/100
# 28/28 [==============================] - 7s 240ms/step - loss: 0.5373 - accuracy: 0.7290 - val_loss: 0.5577 - val_accuracy: 0.7043 - lr: 0.0030
# Epoch 4/100
# 28/28 [==============================] - 7s 242ms/step - loss: 0.5020 - accuracy: 0.7532 - val_loss: 0.5314 - val_accuracy: 0.7716 - lr: 0.0030
# Epoch 5/100
# 28/28 [==============================] - 7s 233ms/step - loss: 0.4819 - accuracy: 0.7647 - val_loss: 0.5191 - val_accuracy: 0.7589 - lr: 0.0030
# Epoch 6/100
# 28/28 [==============================] - 7s 245ms/step - loss: 0.4830 - accuracy: 0.7699 - val_loss: 0.5131 - val_accuracy: 0.7497 - lr: 0.0030
# Epoch 7/100
# 28/28 [==============================] - 7s 251ms/step - loss: 0.4528 - accuracy: 0.7880 - val_loss: 0.4962 - val_accuracy: 0.7940 - lr: 0.0030
# Epoch 8/100
# 28/28 [==============================] - 7s 234ms/step - loss: 0.4371 - accuracy: 0.7959 - val_loss: 0.5043 - val_accuracy: 0.8049 - lr: 0.0030
# Epoch 9/100
# 28/28 [==============================] - 7s 233ms/step - loss: 0.4135 - accuracy: 0.8093 - val_loss: 0.4794 - val_accuracy: 0.8124 - lr: 0.0030
# Epoch 10/100
# 28/28 [==============================] - 7s 234ms/step - loss: 0.4013 - accuracy: 0.8236 - val_loss: 0.4894 - val_accuracy: 0.8211 - lr: 0.0030
# Epoch 11/100
# 28/28 [==============================] - 6s 232ms/step - loss: 0.3684 - accuracy: 0.8349 - val_loss: 0.4508 - val_accuracy: 0.8331 - lr: 0.0015
# Epoch 12/100
# 28/28 [==============================] - 7s 248ms/step - loss: 0.3633 - accuracy: 0.8409 - val_loss: 0.4624 - val_accuracy: 0.8383 - lr: 0.0015
# Epoch 30/100
# 28/28 [==============================] - 7s 234ms/step - loss: 0.2344 - accuracy: 0.9094 - val_loss: 0.3680 - val_accuracy: 0.8843 - lr: 7.5000e-04
# Epoch 31/100
# 28/28 [==============================] - 7s 248ms/step - loss: 0.2317 - accuracy: 0.9110 - val_loss: 0.3649 - val_accuracy: 0.8861 - lr: 3.7500e-04
# Epoch 32/100
# 28/28 [==============================] - 7s 233ms/step - loss: 0.2266 - accuracy: 0.9115 - val_loss: 0.3625 - val_accuracy: 0.8907 - lr: 3.7500e-04
# Epoch 33/100
# 28/28 [==============================] - 7s 234ms/step - loss: 0.2173 - accuracy: 0.9160 - val_loss: 0.3534 - val_accuracy: 0.8895 - lr: 3.7500e-04
# Epoch 34/100
# 28/28 [==============================] - 7s 233ms/step - loss: 0.2242 - accuracy: 0.9141 - val_loss: 0.3527 - val_accuracy: 0.8901 - lr: 3.7500e-04
# Epoch 35/100
# 28/28 [==============================] - 7s 234ms/step - loss: 0.2125 - accuracy: 0.9136 - val_loss: 0.3486 - val_accuracy: 0.8884 - lr: 3.7500e-04
# Epoch 36/100
# 28/28 [==============================] - 7s 247ms/step - loss: 0.2172 - accuracy: 0.9159 - val_loss: 0.3602 - val_accuracy: 0.8936 - lr: 3.7500e-04
# Epoch 37/100
# 28/28 [==============================] - 7s 233ms/step - loss: 0.2122 - accuracy: 0.9199 - val_loss: 0.3528 - val_accuracy: 0.8964 - lr: 3.7500e-04
# Epoch 38/100
# 28/28 [==============================] - 6s 232ms/step - loss: 0.2072 - accuracy: 0.9193 - val_loss: 0.3600 - val_accuracy: 0.8964 - lr: 3.7500e-04
# Epoch 39/100
# 28/28 [==============================] - 7s 237ms/step - loss: 0.2219 - accuracy: 0.9110 - val_loss: 0.3515 - val_accuracy: 0.8907 - lr: 3.7500e-04
# Epoch 40/100
# 28/28 [==============================] - 7s 237ms/step - loss: 0.2021 - accuracy: 0.9166 - val_loss: 0.3528 - val_accuracy: 0.8964 - lr: 3.7500e-04
# Epoch 41/100
# 28/28 [==============================] - 7s 249ms/step - loss: 0.2034 - accuracy: 0.9202 - val_loss: 0.3464 - val_accuracy: 0.8930 - lr: 1.8750e-04
# Epoch 42/100
# 28/28 [==============================] - 7s 234ms/step - loss: 0.2041 - accuracy: 0.9200 - val_loss: 0.3482 - val_accuracy: 0.8964 - lr: 1.8750e-04
# Epoch 43/100
# 28/28 [==============================] - 7s 234ms/step - loss: 0.1972 - accuracy: 0.9200 - val_loss: 0.3450 - val_accuracy: 0.8918 - lr: 1.8750e-04
# Epoch 44/100
# 28/28 [==============================] - 6s 232ms/step - loss: 0.1987 - accuracy: 0.9210 - val_loss: 0.3428 - val_accuracy: 0.8987 - lr: 1.8750e-04
# Epoch 45/100
# 28/28 [==============================] - 7s 235ms/step - loss: 0.1996 - accuracy: 0.9248 - val_loss: 0.3455 - val_accuracy: 0.8982 - lr: 1.8750e-04
# Epoch 46/100
# Epoch 63/100
# 28/28 [==============================] - 7s 235ms/step - loss: 0.1817 - accuracy: 0.9314 - val_loss: 0.3410 - val_accuracy: 0.9010 - lr: 4.6875e-05
# Epoch 64/100
# 28/28 [==============================] - 7s 235ms/step - loss: 0.1820 - accuracy: 0.9312 - val_loss: 0.3407 - val_accuracy: 0.9010 - lr: 4.6875e-05
# Epoch 65/100
# 28/28 [==============================] - 7s 247ms/step - loss: 0.1873 - accuracy: 0.9310 - val_loss: 0.3417 - val_accuracy: 0.9010 - lr: 4.6875e-05
# Epoch 66/100
# 28/28 [==============================] - 7s 234ms/step - loss: 0.1790 - accuracy: 0.9334 - val_loss: 0.3460 - val_accuracy: 0.9016 - lr: 4.6875e-05
# Epoch 67/100
# 28/28 [==============================] - 7s 235ms/step - loss: 0.1846 - accuracy: 0.9289 - val_loss: 0.3440 - val_accuracy: 0.9028 - lr: 4.6875e-05
# Epoch 68/100
# 28/28 [==============================] - 6s 232ms/step - loss: 0.1827 - accuracy: 0.9334 - val_loss: 0.3416 - val_accuracy: 0.9033 - lr: 4.6875e-05
# Epoch 69/100
# 28/28 [==============================] - 7s 234ms/step - loss: 0.1870 - accuracy: 0.9278 - val_loss: 0.3410 - val_accuracy: 0.9010 - lr: 4.6875e-05
# Epoch 70/100
# 28/28 [==============================] - 7s 248ms/step - loss: 0.1857 - accuracy: 0.9291 - val_loss: 0.3411 - val_accuracy: 0.9028 - lr: 4.6875e-05
# Epoch 71/100
# 28/28 [==============================] - 6s 233ms/step - loss: 0.1824 - accuracy: 0.9308 - val_loss: 0.3396 - val_accuracy: 0.9028 - lr: 2.3438e-05
# Epoch 72/100
# 28/28 [==============================] - 7s 235ms/step - loss: 0.1804 - accuracy: 0.9320 - val_loss: 0.3395 - val_accuracy: 0.9016 - lr: 2.3438e-05
# Epoch 73/100
# 28/28 [==============================] - 7s 235ms/step - loss: 0.1856 - accuracy: 0.9292 - val_loss: 0.3405 - val_accuracy: 0.9005 - lr: 2.3438e-05
# Epoch 74/100
# 28/28 [==============================] - 7s 234ms/step - loss: 0.1792 - accuracy: 0.9318 - val_loss: 0.3384 - val_accuracy: 0.9010 - lr: 2.3438e-05
# Epoch 75/100
# 28/28 [==============================] - 7s 246ms/step - loss: 0.1835 - accuracy: 0.9299 - val_loss: 0.3392 - val_accuracy: 0.9022 - lr: 2.3438e-05
# Epoch 76/100
# 28/28 [==============================] - 6s 232ms/step - loss: 0.1875 - accuracy: 0.9299 - val_loss: 0.3415 - val_accuracy: 0.9016 - lr: 2.3438e-05
# Epoch 77/100
# 28/28 [==============================] - 7s 233ms/step - loss: 0.1814 - accuracy: 0.9279 - val_loss: 0.3421 - val_accuracy: 0.8987 - lr: 2.3438e-05
# Epoch 78/100
# 28/28 [==============================] - 7s 234ms/step - loss: 0.1817 - accuracy: 0.9275 - val_loss: 0.3416 - val_accuracy: 0.8999 - lr: 2.3438e-05
# Epoch 79/100
# 28/28 [==============================] - 7s 243ms/step - loss: 0.1763 - accuracy: 0.9373 - val_loss: 0.3392 - val_accuracy: 0.8999 - lr: 2.3438e-05
# Epoch 80/100
# 28/28 [==============================] - 7s 235ms/step - loss: 0.1824 - accuracy: 0.9343 - val_loss: 0.3404 - val_accuracy: 0.9005 - lr: 2.3438e-05
# Epoch 81/100
# 28/28 [==============================] - 7s 236ms/step - loss: 0.1816 - accuracy: 0.9322 - val_loss: 0.3395 - val_accuracy: 0.9005 - lr: 1.1719e-05
# Epoch 82/100
# 28/28 [==============================] - 7s 235ms/step - loss: 0.1749 - accuracy: 0.9363 - val_loss: 0.3386 - val_accuracy: 0.9005 - lr: 1.1719e-05
# Epoch 83/100
# 28/28 [==============================] - 7s 234ms/step - loss: 0.1802 - accuracy: 0.9301 - val_loss: 0.3380 - val_accuracy: 0.8993 - lr: 1.1719e-05
# Epoch 84/100
# 28/28 [==============================] - 7s 250ms/step - loss: 0.1788 - accuracy: 0.9354 - val_loss: 0.3416 - val_accuracy: 0.9022 - lr: 1.1719e-05
# Epoch 85/100
# 28/28 [==============================] - 7s 234ms/step - loss: 0.1815 - accuracy: 0.9312 - val_loss: 0.3407 - val_accuracy: 0.9005 - lr: 1.1719e-05
# Epoch 86/100
# 28/28 [==============================] - 6s 231ms/step - loss: 0.1722 - accuracy: 0.9348 - val_loss: 0.3393 - val_accuracy: 0.9016 - lr: 1.1719e-05
# Epoch 87/100
# 28/28 [==============================] - 6s 233ms/step - loss: 0.1870 - accuracy: 0.9314 - val_loss: 0.3388 - val_accuracy: 0.9005 - lr: 1.1719e-05
# Epoch 88/100
# 28/28 [==============================] - 6s 232ms/step - loss: 0.1770 - accuracy: 0.9315 - val_loss: 0.3372 - val_accuracy: 0.9016 - lr: 1.1719e-05
# Epoch 89/100
# 28/28 [==============================] - 7s 249ms/step - loss: 0.1743 - accuracy: 0.9367 - val_loss: 0.3436 - val_accuracy: 0.9016 - lr: 1.1719e-05
# Epoch 90/100
# 28/28 [==============================] - 7s 235ms/step - loss: 0.1728 - accuracy: 0.9347 - val_loss: 0.3431 - val_accuracy: 0.8982 - lr: 1.1719e-05
# Epoch 91/100
# 28/28 [==============================] - 7s 235ms/step - loss: 0.1880 - accuracy: 0.9276 - val_loss: 0.3432 - val_accuracy: 0.8999 - lr: 5.8594e-06
# Epoch 92/100
# 28/28 [==============================] - 7s 237ms/step - loss: 0.1787 - accuracy: 0.9354 - val_loss: 0.3422 - val_accuracy: 0.8993 - lr: 5.8594e-06
# Epoch 93/100
# 28/28 [==============================] - 7s 237ms/step - loss: 0.1723 - accuracy: 0.9354 - val_loss: 0.3412 - val_accuracy: 0.8976 - lr: 5.8594e-06
# Epoch 94/100
# 28/28 [==============================] - 7s 248ms/step - loss: 0.1836 - accuracy: 0.9333 - val_loss: 0.3399 - val_accuracy: 0.8993 - lr: 5.8594e-06
# Epoch 95/100
# 28/28 [==============================] - 7s 232ms/step - loss: 0.1825 - accuracy: 0.9301 - val_loss: 0.3465 - val_accuracy: 0.9010 - lr: 5.8594e-06
# Epoch 96/100
# 28/28 [==============================] - 7s 235ms/step - loss: 0.1779 - accuracy: 0.9327 - val_loss: 0.3441 - val_accuracy: 0.8999 - lr: 5.8594e-06
# Epoch 97/100
# 28/28 [==============================] - 7s 235ms/step - loss: 0.1850 - accuracy: 0.9271 - val_loss: 0.3419 - val_accuracy: 0.9010 - lr: 5.8594e-06
# Epoch 98/100
# 28/28 [==============================] - 7s 235ms/step - loss: 0.1799 - accuracy: 0.9275 - val_loss: 0.3411 - val_accuracy: 0.9016 - lr: 5.8594e-06
# Epoch 99/100
# 28/28 [==============================] - 7s 252ms/step - loss: 0.1780 - accuracy: 0.9351 - val_loss: 0.3395 - val_accuracy: 0.9005 - lr: 5.8594e-06
# Epoch 100/100
# 28/28 [==============================] - 7s 235ms/step - loss: 0.1795 - accuracy: 0.9348 - val_loss: 0.3392 - val_accuracy: 0.8999 - lr: 5.8594e-06
# 55/55 [==============================] - 1s 13ms/step - loss: 0.3392 - accuracy: 0.8999
# Test Loss: 0.33917707204818726
# Test Accuracy: 0.8998849391937256

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

plt.figure(figsize=(5, 4))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Learning Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
y_pred = model.predict([X_test_eeg, X_test_features])
y_pred_binary = np.round(y_pred).flatten()

#confusion matrix
cm = confusion_matrix(y_test, y_pred_binary)

#classification report
target_names = ['Control', 'Concussed']
report = classification_report(y_test, y_pred_binary, target_names=target_names)
print("\n\nClassification Report:")
print(report)
cr = classification_report(y_test, y_pred_binary)

print("\n\nConfusion Matrix:")
print(cm)
print("\n")
# Out:
# 55/55 [==============================] - 1s 22ms/step
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Control       0.89      0.85      0.87       660
#    Concussed       0.91      0.93      0.92      1078
#
#     accuracy                           0.90      1738
#    macro avg       0.90      0.89      0.89      1738
# weighted avg       0.90      0.90      0.90      1738
#
#
#
# Confusion Matrix:
# [[ 558  102]
#  [  72 1006]]

# %%
#loss curve
plt.figure(figsize=(5, 4))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

y_pred_binary = (y_pred >= 0.5).astype(int)
cm = confusion_matrix(y_test, y_pred_binary)

group_percentages = ["{0:.2%}".format(value) for value in cm.flatten() / np.sum(cm)]
group_counts = ["{0:0.0f}".format(value) for value in cm.flatten()]

labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2, 2)

plt.figure(figsize=(5, 4))
ax = sns.heatmap(cm, fmt='', annot=labels, cmap='Greens')
ax.set_title('Confusion Matrix\n')
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('\nActual Values\n')
ax.xaxis.set_ticklabels(target_names)
ax.yaxis.set_ticklabels(target_names)

plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # sample_index = 1
#
# input_sample_eeg = X_test_eeg[sample_index]
# input_sample_features = X_test_features[sample_index]
# true_label = y_test[sample_index]
# input_sample_eeg = np.expand_dims(input_sample_eeg, axis=0)
# input_sample_features = np.expand_dims(input_sample_features, axis=0)
# prediction = model.predict([input_sample_eeg, input_sample_features])
# binary_prediction = 1 if prediction > 0.5 else 0
# is_correct = binary_prediction == true_label
# print("Input EEG shape:", input_sample_eeg.shape)
# print("Input features shape:", input_sample_features.shape)
# print("True Label:", true_label)
# print("Predicted Label:", binary_prediction)
# print("Prediction is Correct:", is_correct)
