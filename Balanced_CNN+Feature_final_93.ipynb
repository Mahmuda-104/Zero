# %%
import os
import scipy.io
import numpy as np
from scipy import signal

data_path = "/kaggle/input/control1"
lowcut = 0.4 
highcut = 100 
fs_original = 500
fs_new = 250

control_data = []
control_path = os.path.join(data_path, 'Control')

for foldername in os.listdir(control_path):
    subfolder_path = os.path.join(control_path, foldername)
    control_data.append(subfolder_path)

Control30 = []

for control_data_path in control_data:
    n_epochs = 70 
    start_epoch = 1
    end_epoch = 110

    control_arr = []

    for i in range(start_epoch, end_epoch+1):
        epoch_path = os.path.join(control_data_path, f"trial{i}.mat")
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        f0 = 60 
        Q = 30  
        w0 = f0 / (fs_original / 2)
        b, a = signal.iirnotch(w0, Q)
        filtered_data = signal.lfilter(b, a, mat_data1)
        
        # Downsampling
        num_samples_original = filtered_data.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(filtered_data, num_samples_new, axis=-1)
        
        control_arr.append(downsampled_data)
        Control30.append(downsampled_data)

Control30 = np.array(Control30)

print(Control30.shape)
# Out:
# (3300, 60, 1000)

# %%
import os
import scipy.io
import numpy as np
from scipy import signal
data_path = "/kaggle/input/concussed1"
lowcut = 0.4 
highcut = 100 
fs_original = 500
fs_new = 250  

concussed_data = []
concussed_path = os.path.join(data_path, 'Concussed')
for foldername in os.listdir(concussed_path):
    subfolder_path = os.path.join(concussed_path, foldername)
    concussed_data.append(subfolder_path)
    
Concussed52 = []
for concussed_data_path in concussed_data:
    n_epochs = 70
    start_epoch = 1
    end_epoch = 110
    concussed_arr = []

    for i in range(start_epoch, end_epoch+1):
        epoch_path = f"{concussed_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        f0 = 60 
        Q = 30  
        w0 = f0 / (fs_original / 2)
        b, a = signal.iirnotch(w0, Q)
        filtered_data = signal.lfilter(b, a, mat_data1)
        
        # Downsampling
        num_samples_original = filtered_data.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(filtered_data, num_samples_new, axis=-1)
        
        concussed_arr.append(np.array(downsampled_data))
        
        Concussed52.append(downsampled_data)

Concussed52 = np.array(Concussed52)

print( Concussed52.shape)
# Out:
# (5390, 60, 1000)

# %%
import numpy as np
num_control = Control30.shape[0]
num_concussed = Concussed52.shape[0]

desired_num_control = num_concussed
num_oversampling = desired_num_control // num_control
oversampled_control = np.repeat(Control30, num_oversampling, axis=0)

num_additional_samples = desired_num_control - oversampled_control.shape[0]
additional_control_indices = np.random.choice(num_control, size=num_additional_samples, replace=True)
additional_control = Control30[additional_control_indices]
Control30= np.concatenate([oversampled_control,additional_control],axis=0)

# %%
import numpy as np
from scipy.stats import entropy
from scipy import signal

epsilon = 1e-8
alpha_band = (8, 12)
beta_band = (12, 30)
delta_band = (0.5, 4)

num_samples = Control30.shape[0]
num_channels = Control30.shape[1]

features_control = np.zeros((num_samples, num_channels, 4))

for sample_idx in range(num_samples):
    for channel_idx in range(num_channels):
        channel_data = Control30[sample_idx, channel_idx, :]

        freq_spectrum = np.fft.fft(channel_data)
        power_spectrum = np.abs(freq_spectrum) ** 2

        alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
        beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
        delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

        channel_min_value = np.min(channel_data)
        channel_max_value = np.max(channel_data)

        power_spectrum_adjusted = power_spectrum + epsilon
        entropy_values = entropy(power_spectrum_adjusted)

        values = np.array([alpha_power, beta_power, delta_power, entropy_values])
        rescaled_values = (values - values.min()) * (channel_max_value - channel_min_value) / (values.max() - values.min()) + channel_min_value

        features_control[sample_idx, channel_idx, :] = rescaled_values

print(features_control.shape)
# Out:
# (5390, 60, 4)

# %%
import numpy as np
from scipy.stats import entropy
from scipy import signal

epsilon = 1e-8
alpha_band = (8, 12)
beta_band = (12, 30)
delta_band = (0.5, 4)

num_samples = Concussed52.shape[0]
num_channels = Concussed52.shape[1]
features_concussed = np.zeros((num_samples, num_channels, 4))

for sample_idx in range(num_samples):
    for channel_idx in range(num_channels):
        channel_data = Concussed52[sample_idx, channel_idx, :]

        freq_spectrum = np.fft.fft(channel_data)
        power_spectrum = np.abs(freq_spectrum) ** 2

        alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
        beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
        delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

        channel_min_value = np.min(channel_data)
        channel_max_value = np.max(channel_data)

        power_spectrum_adjusted = power_spectrum + epsilon
        entropy_values = entropy(power_spectrum_adjusted)

        values = np.array([alpha_power, beta_power, delta_power, entropy_values])
        rescaled_values = (values - values.min()) * (channel_max_value - channel_min_value) / (values.max() - values.min()) + channel_min_value

        features_concussed[sample_idx, channel_idx, :] = rescaled_values

print(features_concussed.shape)
# Out:
# (5390, 60, 4)

# %%
dataset = np.concatenate([Control30, Concussed52], axis=0)
labels = np.concatenate([np.zeros(desired_num_control), np.ones(num_concussed)], axis=0)

print(dataset.shape) 
print(labels.shape)
# Out:
# (10780, 60, 1000)
# (10780,)

# %%
print(Control30.shape)
print(Concussed52.shape)
# Out:
# (5390, 60, 1000)
# (5390, 60, 1000)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, concatenate, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping

X_train_control, X_test_control, y_train_control, y_test_control = train_test_split(Control30, np.zeros(Control30.shape[0]), test_size=0.2, random_state=42)
X_train_concussed, X_test_concussed, y_train_concussed, y_test_concussed = train_test_split(Concussed52, np.ones(Concussed52.shape[0]), test_size=0.2, random_state=42)

X_train_features_control, X_test_features_control, _, _ = train_test_split(features_control, np.zeros(features_control.shape[0]), test_size=0.2, random_state=42)
X_train_features_concussed, X_test_features_concussed, _, _ = train_test_split(features_concussed, np.ones(features_concussed.shape[0]), test_size=0.2, random_state=42)
X_train_eeg = np.concatenate((X_train_control, X_train_concussed))
X_test_eeg = np.concatenate((X_test_control, X_test_concussed))
X_train_features = np.concatenate((X_train_features_control, X_train_features_concussed))
X_test_features = np.concatenate((X_test_features_control, X_test_features_concussed))
y_train = np.concatenate((y_train_control, y_train_concussed))
y_test = np.concatenate((y_test_control, y_test_concussed))

eeg_input = Input(shape=(60, 1000))
conv1 = Conv1D(64, 3, activation='relu')(eeg_input)
maxpool1 = MaxPooling1D(2)(conv1)
flatten1 = Flatten()(maxpool1)
dropout1 = Dropout(0.5)(flatten1)

feature_input = Input(shape=(60, 4))
flatten2 = Flatten()(feature_input)

concatenated = concatenate([dropout1, flatten2])
batchnorm1 = BatchNormalization()(concatenated)

dense1 = Dense(128, activation='relu')(batchnorm1)
dropout2 = Dropout(0.5)(dense1)

output = Dense(1, activation='sigmoid')(dropout2)

model = Model(inputs=[eeg_input, feature_input], outputs=output)
model.compile(optimizer=Adam(learning_rate=0.003), loss='binary_crossentropy', metrics=['accuracy'])

def lr_scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch > 0:
        return lr * 0.5
    return lr

lr_callback = LearningRateScheduler(lr_scheduler)

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
history = model.fit([X_train_eeg, X_train_features], y_train, epochs=100, batch_size=256, validation_data=([X_test_eeg, X_test_features], y_test), callbacks=[lr_callback, early_stopping])
test_loss, test_accuracy = model.evaluate([X_test_eeg, X_test_features], y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Epoch 1/100
# 34/34 [==============================] - 12s 293ms/step - loss: 0.8076 - accuracy: 0.6111 - val_loss: 0.8544 - val_accuracy: 0.6220 - lr: 0.0030
# Epoch 2/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.6215 - accuracy: 0.6848 - val_loss: 0.5707 - val_accuracy: 0.6851 - lr: 0.0030
# Epoch 3/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5234 - accuracy: 0.7352 - val_loss: 0.5270 - val_accuracy: 0.7644 - lr: 0.0030
# Epoch 4/100
# 34/34 [==============================] - 8s 240ms/step - loss: 0.4945 - accuracy: 0.7603 - val_loss: 0.4974 - val_accuracy: 0.7982 - lr: 0.0030
# Epoch 5/100
# 34/34 [==============================] - 9s 252ms/step - loss: 0.4696 - accuracy: 0.7737 - val_loss: 0.4760 - val_accuracy: 0.8131 - lr: 0.0030
# Epoch 6/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.4274 - accuracy: 0.7977 - val_loss: 0.4508 - val_accuracy: 0.8210 - lr: 0.0030
# Epoch 7/100
# 34/34 [==============================] - 8s 240ms/step - loss: 0.4017 - accuracy: 0.8202 - val_loss: 0.4221 - val_accuracy: 0.8562 - lr: 0.0030
# Epoch 8/100
# 34/34 [==============================] - 8s 241ms/step - loss: 0.3902 - accuracy: 0.8282 - val_loss: 0.4213 - val_accuracy: 0.8377 - lr: 0.0030
# Epoch 9/100
# 34/34 [==============================] - 9s 252ms/step - loss: 0.3547 - accuracy: 0.8449 - val_loss: 0.4036 - val_accuracy: 0.8678 - lr: 0.0030
# Epoch 10/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.3348 - accuracy: 0.8532 - val_loss: 0.3995 - val_accuracy: 0.8622 - lr: 0.0030
# Epoch 11/100
# 34/34 [==============================] - 8s 241ms/step - loss: 0.3255 - accuracy: 0.8662 - val_loss: 0.3796 - val_accuracy: 0.8868 - lr: 0.0015
# Epoch 12/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.2937 - accuracy: 0.8745 - val_loss: 0.3814 - val_accuracy: 0.8752 - lr: 0.0015
# Epoch 13/100
# 34/34 [==============================] - 9s 255ms/step - loss: 0.2831 - accuracy: 0.8852 - val_loss: 0.3682 - val_accuracy: 0.8724 - lr: 0.0015
# Epoch 14/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.2705 - accuracy: 0.8949 - val_loss: 0.3646 - val_accuracy: 0.8854 - lr: 0.0015
# Epoch 15/100
# 34/34 [==============================] - 8s 243ms/step - loss: 0.2709 - accuracy: 0.8919 - val_loss: 0.3544 - val_accuracy: 0.8868 - lr: 0.0015
# Epoch 16/100
# 34/34 [==============================] - 8s 241ms/step - loss: 0.2609 - accuracy: 0.8989 - val_loss: 0.3409 - val_accuracy: 0.9049 - lr: 0.0015
# Epoch 17/100
# 34/34 [==============================] - 9s 254ms/step - loss: 0.2471 - accuracy: 0.9020 - val_loss: 0.3339 - val_accuracy: 0.9147 - lr: 0.0015
# Epoch 18/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.2553 - accuracy: 0.9013 - val_loss: 0.3438 - val_accuracy: 0.9012 - lr: 0.0015
# Epoch 19/100
# 34/34 [==============================] - 8s 243ms/step - loss: 0.2277 - accuracy: 0.9091 - val_loss: 0.3243 - val_accuracy: 0.8998 - lr: 0.0015
# Epoch 20/100
# 34/34 [==============================] - 9s 259ms/step - loss: 0.2264 - accuracy: 0.9119 - val_loss: 0.3191 - val_accuracy: 0.9086 - lr: 0.0015
# Epoch 21/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.2158 - accuracy: 0.9134 - val_loss: 0.3221 - val_accuracy: 0.9133 - lr: 7.5000e-04
# Epoch 22/100
# 34/34 [==============================] - 8s 244ms/step - loss: 0.1993 - accuracy: 0.9258 - val_loss: 0.3177 - val_accuracy: 0.8938 - lr: 7.5000e-04
# Epoch 23/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.2029 - accuracy: 0.9198 - val_loss: 0.3096 - val_accuracy: 0.9179 - lr: 7.5000e-04
# Epoch 24/100
# 34/34 [==============================] - 9s 254ms/step - loss: 0.1932 - accuracy: 0.9236 - val_loss: 0.3065 - val_accuracy: 0.9193 - lr: 7.5000e-04
# Epoch 25/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1987 - accuracy: 0.9218 - val_loss: 0.3087 - val_accuracy: 0.9170 - lr: 7.5000e-04
# Epoch 26/100
# 34/34 [==============================] - 8s 243ms/step - loss: 0.1872 - accuracy: 0.9264 - val_loss: 0.3167 - val_accuracy: 0.9068 - lr: 7.5000e-04
# Epoch 27/100
# 34/34 [==============================] - 8s 244ms/step - loss: 0.1969 - accuracy: 0.9272 - val_loss: 0.3006 - val_accuracy: 0.9202 - lr: 7.5000e-04
# Epoch 28/100
# 34/34 [==============================] - 9s 252ms/step - loss: 0.1789 - accuracy: 0.9324 - val_loss: 0.3052 - val_accuracy: 0.9184 - lr: 7.5000e-04
# Epoch 29/100
# 34/34 [==============================] - 8s 243ms/step - loss: 0.1827 - accuracy: 0.9324 - val_loss: 0.2916 - val_accuracy: 0.9235 - lr: 7.5000e-04
# Epoch 30/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1792 - accuracy: 0.9332 - val_loss: 0.3012 - val_accuracy: 0.9244 - lr: 7.5000e-04
# Epoch 31/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1749 - accuracy: 0.9347 - val_loss: 0.2951 - val_accuracy: 0.9281 - lr: 3.7500e-04
# Epoch 32/100
# 34/34 [==============================] - 9s 256ms/step - loss: 0.1816 - accuracy: 0.9327 - val_loss: 0.2933 - val_accuracy: 0.9300 - lr: 3.7500e-04
# Epoch 33/100
# 34/34 [==============================] - 8s 243ms/step - loss: 0.1631 - accuracy: 0.9382 - val_loss: 0.2888 - val_accuracy: 0.9258 - lr: 3.7500e-04
# Epoch 34/100
# 34/34 [==============================] - 8s 246ms/step - loss: 0.1639 - accuracy: 0.9418 - val_loss: 0.2840 - val_accuracy: 0.9309 - lr: 3.7500e-04
# Epoch 35/100
# 34/34 [==============================] - 8s 249ms/step - loss: 0.1612 - accuracy: 0.9397 - val_loss: 0.2851 - val_accuracy: 0.9263 - lr: 3.7500e-04
# Epoch 36/100
# 34/34 [==============================] - 9s 254ms/step - loss: 0.1558 - accuracy: 0.9414 - val_loss: 0.2828 - val_accuracy: 0.9304 - lr: 3.7500e-04
# Epoch 37/100
# 34/34 [==============================] - 8s 241ms/step - loss: 0.1539 - accuracy: 0.9427 - val_loss: 0.2798 - val_accuracy: 0.9369 - lr: 3.7500e-04
# Epoch 38/100
# 34/34 [==============================] - 9s 256ms/step - loss: 0.1511 - accuracy: 0.9447 - val_loss: 0.2804 - val_accuracy: 0.9346 - lr: 3.7500e-04
# Epoch 39/100
# 34/34 [==============================] - 8s 245ms/step - loss: 0.1482 - accuracy: 0.9446 - val_loss: 0.2803 - val_accuracy: 0.9295 - lr: 3.7500e-04
# Epoch 40/100
# 34/34 [==============================] - 8s 247ms/step - loss: 0.1461 - accuracy: 0.9483 - val_loss: 0.2819 - val_accuracy: 0.9281 - lr: 3.7500e-04
# Epoch 41/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1465 - accuracy: 0.9446 - val_loss: 0.2802 - val_accuracy: 0.9300 - lr: 1.8750e-04
# Epoch 42/100
# 34/34 [==============================] - 8s 240ms/step - loss: 0.1521 - accuracy: 0.9441 - val_loss: 0.2792 - val_accuracy: 0.9337 - lr: 1.8750e-04
# Epoch 43/100
# 34/34 [==============================] - 9s 253ms/step - loss: 0.1477 - accuracy: 0.9455 - val_loss: 0.2805 - val_accuracy: 0.9300 - lr: 1.8750e-04
# Epoch 44/100
# 34/34 [==============================] - 8s 243ms/step - loss: 0.1342 - accuracy: 0.9519 - val_loss: 0.2779 - val_accuracy: 0.9309 - lr: 1.8750e-04
# Epoch 45/100
# 34/34 [==============================] - 8s 243ms/step - loss: 0.1436 - accuracy: 0.9490 - val_loss: 0.2765 - val_accuracy: 0.9327 - lr: 1.8750e-04
# Epoch 46/100
# 34/34 [==============================] - 8s 240ms/step - loss: 0.1457 - accuracy: 0.9450 - val_loss: 0.2761 - val_accuracy: 0.9351 - lr: 1.8750e-04
# Epoch 47/100
# 34/34 [==============================] - 9s 256ms/step - loss: 0.1367 - accuracy: 0.9501 - val_loss: 0.2805 - val_accuracy: 0.9318 - lr: 1.8750e-04
# Epoch 48/100
# 34/34 [==============================] - 8s 243ms/step - loss: 0.1385 - accuracy: 0.9496 - val_loss: 0.2765 - val_accuracy: 0.9351 - lr: 1.8750e-04
# Epoch 49/100
# 34/34 [==============================] - 8s 244ms/step - loss: 0.1336 - accuracy: 0.9525 - val_loss: 0.2745 - val_accuracy: 0.9332 - lr: 1.8750e-04
# Epoch 50/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1522 - accuracy: 0.9465 - val_loss: 0.2752 - val_accuracy: 0.9351 - lr: 1.8750e-04
# Epoch 51/100
# 34/34 [==============================] - 9s 253ms/step - loss: 0.1286 - accuracy: 0.9501 - val_loss: 0.2754 - val_accuracy: 0.9323 - lr: 9.3750e-05
# Epoch 52/100
# 34/34 [==============================] - 8s 240ms/step - loss: 0.1340 - accuracy: 0.9503 - val_loss: 0.2759 - val_accuracy: 0.9337 - lr: 9.3750e-05
# Epoch 53/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1384 - accuracy: 0.9492 - val_loss: 0.2745 - val_accuracy: 0.9374 - lr: 9.3750e-05
# Epoch 54/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1307 - accuracy: 0.9514 - val_loss: 0.2769 - val_accuracy: 0.9309 - lr: 9.3750e-05
# Epoch 55/100
# 34/34 [==============================] - 9s 253ms/step - loss: 0.1365 - accuracy: 0.9512 - val_loss: 0.2749 - val_accuracy: 0.9327 - lr: 9.3750e-05
# Epoch 56/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1348 - accuracy: 0.9506 - val_loss: 0.2747 - val_accuracy: 0.9304 - lr: 9.3750e-05
# Epoch 57/100
# 34/34 [==============================] - 8s 241ms/step - loss: 0.1354 - accuracy: 0.9527 - val_loss: 0.2726 - val_accuracy: 0.9309 - lr: 9.3750e-05
# Epoch 58/100
# 34/34 [==============================] - 8s 243ms/step - loss: 0.1255 - accuracy: 0.9561 - val_loss: 0.2708 - val_accuracy: 0.9314 - lr: 9.3750e-05
# Epoch 59/100
# 34/34 [==============================] - 9s 254ms/step - loss: 0.1308 - accuracy: 0.9540 - val_loss: 0.2722 - val_accuracy: 0.9314 - lr: 9.3750e-05
# Epoch 60/100
# 34/34 [==============================] - 8s 243ms/step - loss: 0.1333 - accuracy: 0.9514 - val_loss: 0.2716 - val_accuracy: 0.9318 - lr: 9.3750e-05
# Epoch 61/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1285 - accuracy: 0.9545 - val_loss: 0.2746 - val_accuracy: 0.9304 - lr: 4.6875e-05
# Epoch 62/100
# 34/34 [==============================] - 8s 243ms/step - loss: 0.1327 - accuracy: 0.9532 - val_loss: 0.2737 - val_accuracy: 0.9300 - lr: 4.6875e-05
# Epoch 63/100
# 34/34 [==============================] - 9s 249ms/step - loss: 0.1270 - accuracy: 0.9538 - val_loss: 0.2754 - val_accuracy: 0.9290 - lr: 4.6875e-05
# Epoch 64/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1344 - accuracy: 0.9520 - val_loss: 0.2743 - val_accuracy: 0.9286 - lr: 4.6875e-05
# Epoch 65/100
# 34/34 [==============================] - 8s 243ms/step - loss: 0.1328 - accuracy: 0.9538 - val_loss: 0.2718 - val_accuracy: 0.9304 - lr: 4.6875e-05
# Epoch 66/100
# 34/34 [==============================] - 9s 254ms/step - loss: 0.1243 - accuracy: 0.9566 - val_loss: 0.2711 - val_accuracy: 0.9309 - lr: 4.6875e-05
# Epoch 67/100
# 34/34 [==============================] - 8s 240ms/step - loss: 0.1339 - accuracy: 0.9515 - val_loss: 0.2726 - val_accuracy: 0.9323 - lr: 4.6875e-05
# Epoch 68/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1246 - accuracy: 0.9549 - val_loss: 0.2717 - val_accuracy: 0.9327 - lr: 4.6875e-05
# Epoch 69/100
# 34/34 [==============================] - 8s 243ms/step - loss: 0.1263 - accuracy: 0.9559 - val_loss: 0.2708 - val_accuracy: 0.9323 - lr: 4.6875e-05
# Epoch 70/100
# 34/34 [==============================] - 9s 253ms/step - loss: 0.1178 - accuracy: 0.9586 - val_loss: 0.2723 - val_accuracy: 0.9295 - lr: 4.6875e-05
# Epoch 71/100
# 34/34 [==============================] - 8s 244ms/step - loss: 0.1298 - accuracy: 0.9540 - val_loss: 0.2714 - val_accuracy: 0.9327 - lr: 2.3438e-05
# Epoch 72/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1287 - accuracy: 0.9547 - val_loss: 0.2694 - val_accuracy: 0.9341 - lr: 2.3438e-05
# Epoch 73/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1202 - accuracy: 0.9563 - val_loss: 0.2687 - val_accuracy: 0.9332 - lr: 2.3438e-05
# Epoch 74/100
# 34/34 [==============================] - 9s 254ms/step - loss: 0.1359 - accuracy: 0.9510 - val_loss: 0.2685 - val_accuracy: 0.9300 - lr: 2.3438e-05
# Epoch 75/100
# 34/34 [==============================] - 8s 243ms/step - loss: 0.1250 - accuracy: 0.9565 - val_loss: 0.2685 - val_accuracy: 0.9304 - lr: 2.3438e-05
# Epoch 76/100
# 34/34 [==============================] - 8s 243ms/step - loss: 0.1252 - accuracy: 0.9565 - val_loss: 0.2678 - val_accuracy: 0.9318 - lr: 2.3438e-05
# Epoch 77/100
# 34/34 [==============================] - 8s 241ms/step - loss: 0.1202 - accuracy: 0.9585 - val_loss: 0.2689 - val_accuracy: 0.9304 - lr: 2.3438e-05
# Epoch 78/100
# 34/34 [==============================] - 9s 253ms/step - loss: 0.1230 - accuracy: 0.9561 - val_loss: 0.2682 - val_accuracy: 0.9309 - lr: 2.3438e-05
# Epoch 79/100
# 34/34 [==============================] - 8s 241ms/step - loss: 0.1165 - accuracy: 0.9572 - val_loss: 0.2674 - val_accuracy: 0.9327 - lr: 2.3438e-05
# Epoch 80/100
# 34/34 [==============================] - 8s 244ms/step - loss: 0.1272 - accuracy: 0.9543 - val_loss: 0.2671 - val_accuracy: 0.9318 - lr: 2.3438e-05
# Epoch 81/100
# 34/34 [==============================] - 8s 240ms/step - loss: 0.1209 - accuracy: 0.9547 - val_loss: 0.2675 - val_accuracy: 0.9318 - lr: 1.1719e-05
# Epoch 82/100
# 34/34 [==============================] - 9s 254ms/step - loss: 0.1217 - accuracy: 0.9544 - val_loss: 0.2667 - val_accuracy: 0.9323 - lr: 1.1719e-05
# Epoch 83/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1239 - accuracy: 0.9563 - val_loss: 0.2665 - val_accuracy: 0.9323 - lr: 1.1719e-05
# Epoch 84/100
# 34/34 [==============================] - 8s 245ms/step - loss: 0.1233 - accuracy: 0.9570 - val_loss: 0.2656 - val_accuracy: 0.9323 - lr: 1.1719e-05
# Epoch 85/100
# 34/34 [==============================] - 9s 258ms/step - loss: 0.1268 - accuracy: 0.9555 - val_loss: 0.2660 - val_accuracy: 0.9337 - lr: 1.1719e-05
# Epoch 86/100
# 34/34 [==============================] - 8s 245ms/step - loss: 0.1313 - accuracy: 0.9537 - val_loss: 0.2655 - val_accuracy: 0.9341 - lr: 1.1719e-05
# Epoch 87/100
# 34/34 [==============================] - 8s 243ms/step - loss: 0.1217 - accuracy: 0.9570 - val_loss: 0.2662 - val_accuracy: 0.9318 - lr: 1.1719e-05
# Epoch 88/100
# 34/34 [==============================] - 8s 240ms/step - loss: 0.1221 - accuracy: 0.9567 - val_loss: 0.2672 - val_accuracy: 0.9300 - lr: 1.1719e-05
# Epoch 89/100
# 34/34 [==============================] - 9s 254ms/step - loss: 0.1287 - accuracy: 0.9521 - val_loss: 0.2662 - val_accuracy: 0.9318 - lr: 1.1719e-05
# Epoch 90/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1263 - accuracy: 0.9572 - val_loss: 0.2665 - val_accuracy: 0.9309 - lr: 1.1719e-05
# Epoch 91/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1207 - accuracy: 0.9592 - val_loss: 0.2663 - val_accuracy: 0.9327 - lr: 5.8594e-06
# Epoch 92/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1216 - accuracy: 0.9588 - val_loss: 0.2655 - val_accuracy: 0.9351 - lr: 5.8594e-06
# Epoch 93/100
# 34/34 [==============================] - 9s 252ms/step - loss: 0.1260 - accuracy: 0.9564 - val_loss: 0.2666 - val_accuracy: 0.9337 - lr: 5.8594e-06
# Epoch 94/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1202 - accuracy: 0.9566 - val_loss: 0.2671 - val_accuracy: 0.9351 - lr: 5.8594e-06
# Epoch 95/100
# 34/34 [==============================] - 8s 242ms/step - loss: 0.1192 - accuracy: 0.9566 - val_loss: 0.2662 - val_accuracy: 0.9341 - lr: 5.8594e-06
# Epoch 96/100
# 34/34 [==============================] - 8s 244ms/step - loss: 0.1299 - accuracy: 0.9570 - val_loss: 0.2658 - val_accuracy: 0.9351 - lr: 5.8594e-06
# Epoch 97/100
# 34/34 [==============================] - 9s 270ms/step - loss: 0.1268 - accuracy: 0.9556 - val_loss: 0.2661 - val_accuracy: 0.9337 - lr: 5.8594e-06
# Epoch 98/100
# 34/34 [==============================] - 8s 245ms/step - loss: 0.1232 - accuracy: 0.9563 - val_loss: 0.2670 - val_accuracy: 0.9346 - lr: 5.8594e-06
# Epoch 99/100
# 34/34 [==============================] - 8s 245ms/step - loss: 0.1266 - accuracy: 0.9566 - val_loss: 0.2664 - val_accuracy: 0.9337 - lr: 5.8594e-06
# Epoch 100/100
# 34/34 [==============================] - 16s 484ms/step - loss: 0.1251 - accuracy: 0.9548 - val_loss: 0.2682 - val_accuracy: 0.9332 - lr: 5.8594e-06
# 68/68 [==============================] - 2s 27ms/step - loss: 0.2682 - accuracy: 0.9332
# Test Loss: 0.2682090103626251
# Test Accuracy: 0.9332096576690674

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

plt.figure(figsize=(5, 4))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Learning Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
y_pred = model.predict([X_test_eeg, X_test_features])
y_pred_binary = np.round(y_pred).flatten()

#confusion matrix
cm = confusion_matrix(y_test, y_pred_binary)

#classification report
target_names = ['Control', 'Concussed']
report = classification_report(y_test, y_pred_binary, target_names=target_names)
print("\n\nClassification Report:")
print(report)
cr = classification_report(y_test, y_pred_binary)

print("\n\nConfusion Matrix:")
print(cm)
print("\n")
# Out:
# 68/68 [==============================] - 1s 14ms/step
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Control       0.91      0.96      0.93      1078
#    Concussed       0.95      0.91      0.93      1078
#
#     accuracy                           0.93      2156
#    macro avg       0.93      0.93      0.93      2156
# weighted avg       0.93      0.93      0.93      2156
#
#
#
# Confusion Matrix:
# [[1030   48]
#  [  96  982]]

# %%
#loss curve
plt.figure(figsize=(5, 4))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

y_pred_binary = (y_pred >= 0.5).astype(int)
cm = confusion_matrix(y_test, y_pred_binary)

group_percentages = ["{0:.2%}".format(value) for value in cm.flatten() / np.sum(cm)]
group_counts = ["{0:0.0f}".format(value) for value in cm.flatten()]

labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2, 2)

plt.figure(figsize=(5, 4))
ax = sns.heatmap(cm, fmt='', annot=labels, cmap='Greens')
ax.set_title('Confusion Matrix\n')
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('\nActual Values\n')
ax.xaxis.set_ticklabels(target_names)
ax.yaxis.set_ticklabels(target_names)

plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %%
TP = 1030
FN = 48
FP = 96
TN = 982

Precision = TP / (TP + FP)
Sensitivity = TP / (TP + FN)
Specificity = TN /(TN + FP)
False_Pos_Rate = FP / (TN + FP)
False_Neg_Rate = FN / (FN + TP)
F1_Score = (2*Precision*Sensitivity) / (Precision + Sensitivity)
Accuracy = (TP+TN) / (TP+FP+TN+FN)

precision = "{:.2f}".format(Precision)
sensitivity = "{:.2f}".format(Sensitivity)
specificity = "{:.2f}".format(Specificity)
false_pos_rate = "{:.2f}".format(False_Pos_Rate)
false_neg_rate = "{:.2f}".format(False_Neg_Rate)
f1_score = "{:.2f}".format(F1_Score)
accuracy = "{:.2f}".format(Accuracy)

print("Precision          :", precision)
print("Sensitivity        :", sensitivity)
print("Specificity        :", specificity)
print("F1-Score           :", f1_score)
print("False Positive Rate:", false_pos_rate)
print("False Negative Rate:", false_neg_rate)
print("Accuraccy          :", accuracy)
# Out:
# Precision          : 0.91
# Sensitivity        : 0.96
# Specificity        : 0.91
# F1-Score           : 0.93
# False Positive Rate: 0.09
# False Negative Rate: 0.04
# Accuraccy          : 0.93
